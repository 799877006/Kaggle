# %%
import pandas as pd
import os

df1 = pd.read_csv('dataset/miyousheQA.csv')
df2=pd.read_csv('/home/yangrumei/Kaggle/dataset/chinese_qa_train.csv')
df3 = pd.read_csv('/home/yangrumei/Kaggle/dataset/cleaned_data_no_nan.csv')

# %%
df1
# Out:
#                      title                                            content
# 0           这次砂糖武装为什么这么好用？  下半龙蜥自己扣了一大堆血，高频攻击次数盾成摆设，大姐头的盾还能吃到真伤buff，开服队伍的含...
# 1        那维莱特的突破材料采集路线有哪些？                       79个幽光星星的采集路线由“要和我一起去炸鱼吗m”提供。
# 2      那维莱特的武器和圣遗物选择有哪些建议？                        “地底Tv”提供了那维莱特武器和圣遗物的伤害对比分析。
# 3       钟离的养成材料有哪些快速收集的路线？                            168个石珀可以通过特定的快速收集路线来获取。
# 4      钟离的适配武器和圣遗物选择有哪些推荐？  钟离的适配武器和最优圣遗物选择可以参考一图流角色解析攻略，其中详细列出了推荐的装备和毕业面板要求。
# ...                    ...                                                ...
# 43868       芭芭拉的战斗天赋有哪些特点？  芭芭拉的普通攻击能造成水元素伤害并施加潮湿状态，重击消耗体力造成大范围水元素伤害。她的元素战...
# 43869         芭芭拉的核心天赋是什么？        芭芭拉的核心天赋是“真心为你”，能提高队伍中所有角色的受治疗加成，对芭芭拉的提升较高。
# 43870    北斗在前期和后期适合使用哪些装备？  前期适合使用踏火息雷和不屈等三星武器，以及血战之人套、行者之心套和武人套等圣遗物；后期则适合...
# 43871       魈的元素战技有什么独特之处？  魈的元素战技可以在空中释放，这是其他角色的元素战技所不具备的独特机制，使其能够与重击串联使用...
# 43872     魈的被动技能如何影响其战斗方式？  魈的被动技能直接提升重击伤害，但不加成普通攻击，这决定了魈的战斗方式以重击为主，适合持续站场...
#
# [43873 rows x 2 columns]

# %%
df2.columns=['title','content']

# %%
df2
# Out:
#                                                    title  content
# 0                          哪位在美国出生的辛克莱于 1930 年获得了诺贝尔文学奖？  辛克莱·刘易斯
# 1                                      朱迪·丹奇女爵在英格兰的哪里出生？       约克
# 2                                公告牌杂志首次出版美国热门排行榜是在哪个十年？     30 秒
# 3                                  安哥拉在 1975 年从哪个国家获得独立？      葡萄牙
# 4                                           大卫·索尔来自哪个城市？      芝加哥
# ...                                                  ...      ...
# 33587                     马丁·斯科塞斯 2008 年关于滚石乐队的纪录片叫什么名字？     闪耀光芒
# 33588  谁于1812年在朴次茅斯附近出生，童年在查塔姆和伦敦度过，1836年与凯瑟琳·霍加斯结婚，1...  查尔斯·狄更斯
# 33589                 美国队在印第安纳波利斯举行的 2002 年男篮世锦赛上获得了第几名？    阿根廷队。
# 33590                                比吉斯组合中的哪两个吉布兄弟是双胞胎？   罗宾和莫里斯
# 33591                       目前俄罗斯东正教会的基督教新年在西方公历中的日期是哪天？    1月14日
#
# [33592 rows x 2 columns]

# %%
df3
# Out:
#         post_id                           title  \
# 0      59513958  【V5.2攻略·角色攻略】恰斯卡·全面解析︱养成/配队/机制
# 1      60229934                     这次砂糖武装也太好用了
# 2      59425259                 【观测枢】欧洛伦一图流速览攻略
# 3      60122180  【一图看懂】那维莱特/钟离/瑶瑶/菲谢尔/鹿野院平藏｜一图流
# 4      60105697           那维莱特 | 材料采集·角色培养 攻略合集
# ...         ...                             ...
# 20202    973540          【冒险备忘录】护法夜叉——魈 全方位角色攻略
# 20203   1020527  【猫の天空岛旅游团】凝光：我有特殊的充电方法——野外充电详解
# 20204   1020510         【原初之鱼】「闪耀偶像」芭芭拉-全方面角色攻略
# 20205   1010883     听凭风引！蒲公英骑士——琴 | 角色解析首发！（申精）
# 20206    946598     【冒险备忘录】守护璃月的仙人——魈 角色技能介绍&攻略
#
#                                                  content
# 0      \t这里是阿斯盖特，本期是“花羽会”的调停人——『恰斯卡』的角色攻略！ \t以下将从养成、配...
# 1      下半龙蜥自己扣了一大堆血，高频攻击次数盾成摆设，大姐头的盾还能吃到真伤buff开服队伍含金量...
# 2      嗨嗨各位旅行者们，大家好啊，5.2版本迎来了纳塔第二位四星，也是全游第一位实装的雷系成男，我...
# 3      这里是阿斯盖特！本期是【5.2下半卡池一图流】，包含复刻角色那维莱特（5★）、钟离（5★）、...
# 4       ┏本帖包含以下攻略内容材料采集角色培养往期合集┛ hello，各位旅行者大家好呀~ 这里是...
# ...

# %%
train_dataset = pd.concat([df1,df2,df3],ignore_index=True)

# %%
train_dataset.to_csv('dataset/train_dataset.csv',index=False)
